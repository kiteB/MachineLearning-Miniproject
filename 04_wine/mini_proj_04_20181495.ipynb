# %% [markdown]
# # ML miniproject #4

# %% [markdown]
# * 레드 와인 품질 예측

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# -> quality가 비슷한 라벨이 연속으로 나옴 -> 데이터 섞어주기

# %%
from sklearn.utils import shuffle
df = shuffle(df)

# %%
df.head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 858           11.7              0.28         0.47             1.7      0.054
# 347           13.8              0.49         0.67             3.0      0.093
# 369            9.4              0.27         0.53             2.4      0.074
# 872            7.3              0.35         0.24             2.0      0.067
# 561            9.0              0.44         0.49             2.4      0.078
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 858                 17.0                  32.0  0.99686  3.15       0.67
# 347                  6.0                  15.0  0.99860  3.02       0.93
# 369                  6.0                  18.0  0.99620  3.20       1.13
# 872                 28.0                  48.0  0.99576  3.43       0.54
# 561                 26.0                 121.0  0.99780  3.23       0.58
#
#      alcohol  quality
# 858     10.6        7
# 347     12.0        6
# 369     12.0        7
# 872     10.0        4
# 561      9.2        5

# %%
X = df.drop(['quality'], axis=1) # quality 제거
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 858            11.7              0.28         0.47             1.7      0.054
# 347            13.8              0.49         0.67             3.0      0.093
# 369             9.4              0.27         0.53             2.4      0.074
# 872             7.3              0.35         0.24             2.0      0.067
# 561             9.0              0.44         0.49             2.4      0.078
# ...             ...               ...          ...             ...        ...
# 1473            6.1              0.60         0.08             1.8      0.071
# 427             9.5              0.78         0.22             1.9      0.077
# 1289            7.0              0.60         0.30             4.5      0.068
# 528             8.2              0.42         0.49             2.6      0.084
# 923             6.8              0.41         0.31             8.8      0.084
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 858                  17.0                  32.0  0.99686  3.15       0.67
# 347                   6.0                  15.0  0.99860  3.02       0.93
# 369                   6.0                  18.0  0.99620  3.20       1.13
# 872                  28.0                  48.0  0.99576  3.43       0.54
# 561                  26.0                 121.0  0.99780  3.23       0.58
# ...                   ...                   ...      ...   ...        ...
# 1473                 14.0                  45.0  0.99336  3.38       0.54
# 427                   6.0                  32.0  0.99880  3.26       0.56
# 1289                 20.0                 110.0  0.99914  3.30       1.17
# 528                  32.0                  55.0  0.99880  3.34       0.75
# 923                  26.0                  45.0  0.99824  3.38       0.64
#
#       alcohol
# 858      10.6
# 347      12.0
# 369      12.0
# 872      10.0
# 561       9.2
# ...       ...
# 1473     11.0
# 427      10.6
# 1289     10.2
# 528       8.7
# 923      10.1
#
# [1599 rows x 11 columns]

# %%
y = df['quality'] # 데이터셋에서 quality만 분리
y
# Out:
# 858     7
# 347     6
# 369     7
# 872     4
# 561     5
#        ..
# 1473    5
# 427     6
# 1289    5
# 528     6
# 923     6
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=100,random_state=42)
forest_reg.fit(X, y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.model_selection import cross_val_score

forest_scores = cross_val_score(forest_reg, X, y,
                                scoring="neg_mean_squared_error", cv=10) # 교차 검증
forest_rmse_scores = np.sqrt(-forest_scores)
forest_rmse_scores
# Out:
# array([0.57912218, 0.56767178, 0.49056855, 0.53280097, 0.5464825 ,
#        0.54955266, 0.55349402, 0.67106585, 0.53837951, 0.6273013 ])

# %%
forest_rmse_scores.mean()
# Out:
# 0.5656439316794026
